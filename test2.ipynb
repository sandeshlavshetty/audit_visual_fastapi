# %%
from manager import Manager
import os
from llm_config import HF_endpoint
import warnings
from langchain_huggingface import HuggingFaceEndpoint
from langchain_huggingface import ChatHuggingFace
from langchain_openai import AzureChatOpenAI
from typing import Any, Dict, List, Optional, Union
# from dataclasses import dataclass
import base64
from dataclasses import field
from typing import Any, Dict, List, Optional, Union
from pydantic.dataclasses import dataclass
from langchain_core.messages import (
    HumanMessage,
    SystemMessage,
)
model_type = "azureOAi"
llm = HF_endpoint(model_type)

cars_data_url = "https://raw.githubusercontent.com/uwdata/draco/master/data/cars.csv"
# Out:
# Using Azure Model
# Using Azure Model
# Using Azure Model
# Using Azure Model
# Using Azure Model
# Using Azure Model
# Using Azure Model
# Using Azure Model
# Using Azure Model

# %%
sandesh = Manager()

# %%
def test_vizgen():
    summary = sandesh.summarize(
        cars_data_url,
        summary_method="llmt")

    goals = sandesh.goals(summary,llm,n=2)
    charts = sandesh.visualize(
        summary=summary,
        goal=goals[0],
        llm=llm,
        library="seaborn")
    print("test vizgen charts:-"+"\n")
    print(charts)
    assert len(charts) > 0
    first_chart = charts[0]

    # Ensure the first chart has a status of True
    assert first_chart.status is True

    # Ensure no errors in the first chart
    assert first_chart.error is None

    # Ensure the raster image of the first chart exists
    assert len(first_chart.raster) > 0

    # Test saving the raster image of the first chart
    temp_file_path = "temp_image.png"
    first_chart.savefig(temp_file_path)
    # Ensure the image is saved correctly
    assert os.path.exists(temp_file_path)
    # Clean up
    # os.remove(temp_file_path)

# %%
test_vizgen()
# Out:
# data properties:-
# [{'column': 'Name', 'properties': {'dtype': 'string', 'samples': ['Nissan Altima S 4dr', 'Mercury Marauder 4dr', 'Toyota Prius 4dr (gas/electric)'], 'num_unique_values': 385, 'semantic_type': '', 'description': ''}}, {'column': 'Type', 'properties': {'dtype': 'category', 'samples': ['SUV', 'Minivan', 'Sports Car'], 'num_unique_values': 5, 'semantic_type': '', 'description': ''}}, {'column': 'AWD', 'properties': {'dtype': 'int64', 'samples': [1, 0], 'num_unique_values': 2, 'semantic_type': '', 'description': ''}}, {'column': 'RWD', 'properties': {'dtype': 'int64', 'samples': [1, 0], 'num_unique_values': 2, 'semantic_type': '', 'description': ''}}, {'column': 'Retail_Price', 'properties': {'dtype': 'int64', 'samples': [22775, 37245], 'num_unique_values': 370, 'semantic_type': '', 'description': ''}}, {'column': 'Dealer_Cost', 'properties': {'dtype': 'int64', 'samples': [18030, 31558], 'num_unique_values': 384, 'semantic_type': '', 'description': ''}}, {'column': 'Engine_Size__l_', 'properties': {'dtype': 'number', 'std': 1.0266787710109588, 'min': 0.0, 'max': 6.0, 'samples': [2.2, 5.3], 'num_unique_values': 40, 'semantic_type': '', 'description': ''}}, {'column': 'Cyl', 'properties': {'dtype': 'int64', 'samples': [4, 9], 'num_unique_values': 8, 'semantic_type': '', 'description': ''}}, {'column': 'Horsepower_HP_', 'properties': {'dtype': 'int64', 'samples': [126, 138], 'num_unique_values': 100, 'semantic_type': '', 'description': ''}}, {'column': 'City_Miles_Per_Gallon', 'properties': {'dtype': 'int64', 'samples': [59, 32], 'num_unique_values': 29, 'semantic_type': '', 'description': ''}}, {'column': 'Highway_Miles_Per_Gallon', 'properties': {'dtype': 'int64', 'samples': [43, 37], 'num_unique_values': 33, 'semantic_type': '', 'description': ''}}, {'column': 'Weight', 'properties': {'dtype': 'int64', 'samples': [4473, 3472], 'num_unique_values': 315, 'semantic_type': '', 'description': ''}}, {'column': 'Wheel_Base', 'properties': {'dtype': 'int64', 'samples': [110, 0], 'num_unique_values': 34, 'semantic_type': '', 'description': ''}}, {'column': 'Len', 'properties': {'dtype': 'int64', 'samples': [197, 183], 'num_unique_values': 60, 'semantic_type': '', 'description': ''}}, {'column': 'Width', 'properties': {'dtype': 'int64', 'samples': [72, 70], 'num_unique_values': 19, 'semantic_type': '', 'description': ''}}]
# Using Azure Model
# Enrich function working with azure OAi
# {
#   "name": "cars.csv",
#   "file_name": "cars.csv",
#   "dataset_description": "This dataset contains information about cars.",
#   "fields": [
#     {
#       "column": "Name",
#       "properties": {
#         "dtype": "string",
#         "samples": [
#           "Nissan Altima S 4dr",
#           "Mercury Marauder 4dr",
#           "Toyota Prius 4dr (gas/electric)"
#         ],
#         "num_unique_values": 385,
#         "semantic_type": "car_model",
#         "description": "The name of the car model."
#       }
#     },
#     {
#       "column": "Type",
#       "properties": {
#         "dtype": "category",
#         "samples": [
#           "SUV",
#           "Minivan",
#           "Sports Car"
#         ],
#         "num_unique_values": 5,
#         "semantic_type": "car_type",
#         "description": "The type of the car."
#       }
#     },
#     {
#       "column": "AWD",
#       "properties": {
#         "dtype": "int64",
#         "samples": [
#           1,
#           0
#         ],
#         "num_unique_values": 2,
#         "semantic_type": "boolean",
#         "description": "Whether the car has all-wheel drive (1) or not (0)."
#       }
#     },
#     {
#       "column": "RWD",
#       "properties": {
#         "dtype": "int64",
#         "samples": [
#           1,
#           0
#         ],
#         "num_unique_values": 2,
#         "semantic_type": "boolean",
#         "description": "Whether the car has rear-wheel drive (1) or not (0)."
#       }
#     },
#     {
#       "column": "Retail_Price",
#       "properties": {
#         "dtype": "int64",
#         "samples": [
#           22775,
#           37245
#         ],
#         "num_unique_values": 370,
#         "semantic_type": "price",
#         "description": "The retail price of the car."
#       }
#     },
#     {
#       "column": "Dealer_Cost",
#       "properties": {
#         "dtype": "int64",
#         "samples": [
#           18030,
#           31558
#         ],
#         "num_unique_values": 384,
#         "semantic_type": "price",
#         "description": "The cost of the car for the dealer."
#       }
#     },
#     {
#       "column": "Engine_Size__l_",
#       "properties": {
#         "dtype": "number",
#         "std": 1.0266787710109588,
#         "min": 0.0,
#         "max": 6.0,
#         "samples": [
#           2.2,
#           5.3
#         ],
#         "num_unique_values": 40,
#         "semantic_type": "engine_size",
#         "description": "The size of the car's engine in liters."
#       }
#     },
#     {
#       "column": "Cyl",
#       "properties": {
#         "dtype": "int64",
#         "samples": [
#           4,
#           9
#         ],
#         "num_unique_values": 8,
#         "semantic_type": "number_of_cylinders",
#         "description": "The number of cylinders in the car's engine."
#       }
#     },
#     {
#       "column": "Horsepower_HP_",
#       "properties": {
#         "dtype": "int64",
#         "samples": [
#           126,
#           138
#         ],
#         "num_unique_values": 100,
#         "semantic_type": "horsepower",
#         "description": "The horsepower of the car's engine."
#       }
#     },
#     {
#       "column": "City_Miles_Per_Gallon",
#       "properties": {
#         "dtype": "int64",
#         "samples": [
#           59,
#           32
#         ],
#         "num_unique_values": 29,
#         "semantic_type": "fuel_efficiency",
#         "description": "The miles per gallon the car can achieve in city driving."
#       }
#     },
#     {
#       "column": "Highway_Miles_Per_Gallon",
#       "properties": {
#         "dtype": "int64",
#         "samples": [
#           43,
#           37
#         ],
#         "num_unique_values": 33,
#         "semantic_type": "fuel_efficiency",
#         "description": "The miles per gallon the car can achieve on the highway."
#       }
#     },
#     {
#       "column": "Weight",
#       "properties": {
#         "dtype": "int64",
#         "samples": [
#           4473,
#           3472
#         ],
#         "num_unique_values": 315,
#         "semantic_type": "weight",
#         "description": "The weight of the car in pounds."
#       }
#     },
#     {
#       "column": "Wheel_Base",
#       "properties": {
#         "dtype": "int64",
#         "samples": [
#           110,
#           0
#         ],
#         "num_unique_values": 34,
#         "semantic_type": "length",
#         "description": "The wheelbase of the car in inches."
#       }
#     },
#     {
#       "column": "Len",
#       "properties": {
#         "dtype": "int64",
#         "samples": [
#           197,
#           183
#         ],
#         "num_unique_values": 60,
#         "semantic_type": "length",
#         "description": "The length of the car in inches."
#       }
#     },
#     {
#       "column": "Width",
#       "properties": {
#         "dtype": "int64",
#         "samples": [
#           72,
#           70
#         ],
#         "num_unique_values": 19,
#         "semantic_type": "length",
#         "description": "The width of the car in inches."
#       }
#     }
#   ]
# }
# json_string:-
#
# result:-
#
# [
#     {
#         "index": 0,
#         "question": "What is the distribution of car types in the dataset?",
#         "visualization": "bar chart of car types",
#         "rationale": "By visualizing the distribution of car types, we can understand the proportion of each car type in the dataset. This information can be useful for market analysis and understanding consumer preferences."
#     },
#     {
#         "index": 1,
#         "question": "What is the relationship between engine size and horsepower?",
#         "visualization": "scatter plot of engine size vs horsepower",
#         "rationale": "By plotting engine size against horsepower, we can observe any patterns or correlations between these two variables. This can provide insights into the performance and power of different car models."
#     }
# ]
# ```python
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # solution plan
# # i. Use the 'Type' column to get the distribution of car types
# def plot(data: pd.DataFrame):
#     sns.countplot(data=data, x='Type')
#     plt.title('What is the distribution of car types in the dataset?', wrap=True)
#     return plt
#
# chart = plot(data)
# ```
# <class 'str'>
# vizgenearotr result:-
#
# ```python
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # solution plan
# # i. Use the 'Type' column to get the distribution of car types
# def plot(data: pd.DataFrame):
#     sns.countplot(data=data, x='Type')
#     plt.title('What is the distribution of car types in the dataset?', wrap=True)
#     return plt
#
# chart = plot(data)
# ```
# code_specs result:-
#
# ["```python\nimport seaborn as sns\nimport pandas as pd\nimport matplotlib.pyplot as plt\n\n# solution plan\n# i. Use the 'Type' column to get the distribution of car types\ndef plot(data: pd.DataFrame):\n    sns.countplot(data=data, x='Type')\n    plt.title('What is the distribution of car types in the dataset?', wrap=True)\n    return plt\n\nchart = plot(data)\n```"]
# execute function started
# if statement passed
# processcode func called
# strated procescode function
# ended process code function and reuslt it returns is :-
#
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # solution plan
# # i. Use the 'Type' column to get the distribution of car types
# def plot(data: pd.DataFrame):
#     sns.countplot(data=data, x='Type')
#     plt.title('What is the distribution of car types in the dataset?', wrap=True)
#     return plt
#
# chart = plot(data)
# entered get globals function
# get globals function done:-
#
# {'sns': <module 'seaborn' from 'c:\\Users\\sandesh lavshetty\\BOB hack\\audit_visual\\.venv\\Lib\\site-packages\\seaborn\\__init__.py'>, 'pd': <module 'pandas' from 'c:\\Users\\sandesh lavshetty\\BOB hack\\audit_visual\\.venv\\Lib\\site-packages\\pandas\\__init__.py'>, 'plt': <module 'matplotlib.pyplot' from 'c:\\Users\\sandesh lavshetty\\BOB hack\\audit_visual\\.venv\\Lib\\site-packages\\matplotlib\\pyplot.py'>, 'data':                               Name        Type  AWD  RWD  Retail_Price  \
# 0                 Acura 3.5 RL 4dr       Sedan    0    0         43755
# 1    Acura 3.5 RL w/Navigation 4dr       Sedan    0    0         46100
# 2                        Acura MDX         SUV    1    0         36945
# 3     Acura NSX coupe 2dr manual S  Sports Car    0    1         89765
# 4             Acura RSX Type S 2dr       Sedan    0    0         23820
# ..                             ...         ...  ...  ...           ...
# 382              Volvo S80 2.9 4dr       Sedan    0    0         37730
# 383               Volvo S80 T6 4dr       Sedan    0    0         45210
# 384                      Volvo V40       Wagon    0    0         26135
# 385                     Volvo XC70       Wagon    1    0         35145
# 386                  Volvo XC90 T6         SUV    1    0         41250
#
#      Dealer_Cost  Engine_Size__l_  Cyl  Horsepower_HP_  City_Miles_Per_Gallon  \
# 0          39014              3.5    6             225                     18
# 1          41100              3.5    6             225                     18
# 2          33337              3.5    6             265                     17
# 3          79978              3.2    6             290                     17
# 4          21761              2.0    4             200                     24
# ..           ...              ...  ...             ...                    ...
# 382        35542              2.9    6             208                     20
# 383        42573              2.9    6             268                     19
# 384        24641              1.9    4             170                     22
# 385        33112              2.5    5             208                     20
# 386        38851              2.9    6             268                     15
#
#      Highway_Miles_Per_Gallon  Weight  Wheel_Base  Len  Width
# 0                          24    3880         115  197     72
# 1                          24    3893         115  197     72
# 2                          23    4451         106  189     77
# 3                          24    3153         100  174     71
# 4                          31    2778         101  172     68
# ..                        ...     ...         ...  ...    ...
# 382                        28    3576         110  190     72
# 383                        26    3653         110  190     72
# 384                        29    2822         101  180     68
# 385                        27    3823         109  186     73
# 386                        20    4638         113  189     75
#
# [387 rows x 15 columns]}
# ex_locals result:-
#
# {'sns': <module 'seaborn' from 'c:\\Users\\sandesh lavshetty\\BOB hack\\audit_visual\\.venv\\Lib\\site-packages\\seaborn\\__init__.py'>, 'pd': <module 'pandas' from 'c:\\Users\\sandesh lavshetty\\BOB hack\\audit_visual\\.venv\\Lib\\site-packages\\pandas\\__init__.py'>, 'plt': <module 'matplotlib.pyplot' from 'c:\\Users\\sandesh lavshetty\\BOB hack\\audit_visual\\.venv\\Lib\\site-packages\\matplotlib\\pyplot.py'>, 'data':                               Name        Type  AWD  RWD  Retail_Price  \
# 0                 Acura 3.5 RL 4dr       Sedan    0    0         43755
# 1    Acura 3.5 RL w/Navigation 4dr       Sedan    0    0         46100
# 2                        Acura MDX         SUV    1    0         36945
# 3     Acura NSX coupe 2dr manual S  Sports Car    0    1         89765
# 4             Acura RSX Type S 2dr       Sedan    0    0         23820
# ..                             ...         ...  ...  ...           ...
# 382              Volvo S80 2.9 4dr       Sedan    0    0         37730
# 383               Volvo S80 T6 4dr       Sedan    0    0         45210
# 384                      Volvo V40       Wagon    0    0         26135
# 385                     Volvo XC70       Wagon    1    0         35145
# 386                  Volvo XC90 T6         SUV    1    0         41250
#
#      Dealer_Cost  Engine_Size__l_  Cyl  Horsepower_HP_  City_Miles_Per_Gallon  \
# 0          39014              3.5    6             225                     18
# 1          41100              3.5    6             225                     18
# 2          33337              3.5    6             265                     17
# 3          79978              3.2    6             290                     17
# 4          21761              2.0    4             200                     24
# ..           ...              ...  ...             ...                    ...
# 382        35542              2.9    6             208                     20
# 383        42573              2.9    6             268                     19
# 384        24641              1.9    4             170                     22
# 385        33112              2.5    5             208                     20
# 386        38851              2.9    6             268                     15
#
#      Highway_Miles_Per_Gallon  Weight  Wheel_Base  Len  Width
# 0                          24    3880         115  197     72
# 1                          24    3893         115  197     72
# 2                          23    4451         106  189     77
# 3                          24    3153         100  174     71
# 4                          31    2778         101  172     68
# ..                        ...     ...         ...  ...    ...
# 382                        28    3576         110  190     72
# 383                        26    3653         110  190     72
# 384                        29    2822         101  180     68
# 385                        27    3823         109  186     73
# 386                        20    4638         113  189     75
#
# [387 rows x 15 columns]}
# None
# chart print:-
#
# <module 'matplotlib.pyplot' from 'c:\\Users\\sandesh lavshetty\\BOB hack\\audit_visual\\.venv\\Lib\\site-packages\\matplotlib\\pyplot.py'>
# entered if plt
#
# charsts.append function called
# test vizgen charts:-
#
# [<executor.ChartExecutorResponse object at 0x00000275AFAE58E0>]

# %%
from utils import plot_raster
plot_raster("203442706e0")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[5], line 2
#       1 from utils import plot_raster
# ----> 2 plot_raster("203442706e0")
#
# File c:\Users\sandesh lavshetty\BOB hack\audit_visual\utils.py:136, in plot_raster(rasters, figsize)
#     134 max_height = 0
#     135 for raster in rasters:
# --> 136     decoded_image = base64.b64decode(raster)
#     137     image = plt.imread(io.BytesIO(decoded_image), format='PNG')
#     139     max_height = max(max_height, image.shape[0])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\base64.py:88, in b64decode(s, altchars, validate)
#      86     assert len(altchars) == 2, repr(altchars)
#      87     s = s.translate(bytes.maketrans(altchars, b'+/'))
# ---> 88 return binascii.a2b_base64(s, strict_mode=validate)
#
# Error: Incorrect padding
